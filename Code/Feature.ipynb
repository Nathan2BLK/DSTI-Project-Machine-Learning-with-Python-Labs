# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'..\DataBase\books.csv')
df.value_counts()
# Out:
# bookID  title                                                                               authors                                      average_rating  isbn        isbn13         language_code  num_pages  ratings_count  text_reviews_count  publication_date  publisher
# 1       Harry Potter and the Half-Blood Prince (Harry Potter  #6)                           J.K. Rowling/Mary GrandPré                   4.57            0439785960  9780439785969  eng            652        2095690        27591               9/16/2006         Scholastic Inc.                1
# 28533   Well of Darkness (Sovereign Stone  #1)                                              Margaret Weis/Tracy Hickman                  3.67            0061020575  9780061020575  eng            562        2049           49                  9/4/2001          HarperTorch                    1
# 28511   Warrior Angel                                                                       Margaret Weis/Lizz Weis                      3.15            0060833254  9780060833251  en-US          354        242            28                  2/27/2007         Avon                           1
# 28514   Dragons of a Vanished Moon (Dragonlance: The War of Souls  #3)                      Margaret Weis/Tracy Hickman                  3.91            0786929502  9780786929504  eng            610        7506           82                  3/1/2003          Wizards of the Coast           1
# 28522   Starshield: Sentinels                                                               Margaret Weis/Tracy Hickman                  3.57            0345397606  9780345397607  eng            421        182            6                   11/17/1998        Del Rey                        1
#                                                                                                                                                                                                                                                                                                  ..
# 13449   La Milla Verde                                                                      Stephen King/María Eugenia Ciocchini Suárez  4.44            0743233603  9780743233606  spa            448        9              1                   3/26/2002         Fireside Books                 1
# 13451   Storm of the Century                                                                Stephen King                                 3.92            067103264X  9780671032647  eng            376        18255          266                 2/1/1999          Pocket                         1
# 13460   Girls Think of Everything: Stories of Ingenious Inventions by Women                 Catherine Thimmesh/Melissa Sweet             4.15            0618195637  9780618195633  eng            64         906            171                 3/11/2002         HMH Books for Young Readers    1
# 13462   How Dogs Think: What the World Looks Like to Them and Why They Act the Way They Do  Stanley Coren                                3.99            0743222334  9780743222334  en-US          368        693            58                  6/6/2005          Atria Books                    1
# 45641   Las aventuras de Tom Sawyer                                                         Mark Twain                                   3.91            8497646983  9788497646987  spa            272        113            12                  5/28/2006         Edimat Libros                  1
# Name: count, Length: 11127, dtype: int64

# %%
dfwork = df
dfwork['authors'] = df['authors'].str.split('/')

# %%
import spacy
spacy.cli.download("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\util\ssl_.py:470, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     468     pass
# --> 470 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     471 return ssl_sock
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\util\ssl_.py:514, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     512     return SSLTransport(sock, ssl_context, server_hostname)
# --> 514 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\ssl.py:1046, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1045             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1046         self.do_handshake()
#    1047 except (OSError, ValueError):
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\ssl.py:1317, in SSLSocket.do_handshake(self, block)
#    1316         self.settimeout(None)
# -> 1317     self._sslobj.do_handshake()
#    1318 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /explosion/spacy-models/master/compatibility.json (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# c:\REPOSITORIES\Project\DSTI-Project-Machine-Learning-with-Python-Labs\Code\Feature.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> import spacy
# ----> <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> spacy.cli.download("en_core_web_sm")
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\spacy\cli\download.py:70, in download(model, direct, sdist, *pip_args)
#      65         msg.warn(
#      66             f"As of spaCy v3.0, shortcuts like '{model}' are deprecated. Please "
#      67             f"use the full pipeline package name '{OLD_MODEL_SHORTCUTS[model]}' instead."
#      68         )
#      69         model_name = OLD_MODEL_SHORTCUTS[model]
# ---> 70     compatibility = get_compatibility()
#      71     version = get_version(model_name, compatibility)
#      73 filename = get_model_filename(model_name, version, sdist)
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\spacy\cli\download.py:94, in get_compatibility()
#      92 else:
#      93     version = get_minor_version(about.__version__)
# ---> 94 r = requests.get(about.__compatibility__)
#      95 if r.status_code != 200:
#      96     msg.fail(
#      97         f"Server error ({r.status_code})",
#      98         f"Couldn't fetch compatibility table. Please find a package for your spaCy "
#    (...)
#     102         exits=1,
#     103     )
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\requests\adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     513         raise ProxyError(e, request=request)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
# --> 517         raise SSLError(e, request=request)
#     519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /explosion/spacy-models/master/compatibility.json (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)')))

# %%
import spacy
# Charger le modèle SpaCy pré-entraîné
nlp = spacy.load("en_core_web_sm")
# Fonction pour extraire les entités nommées d'un titre
def extract_entities(title):
    doc = nlp(title)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Appliquer la fonction à votre ensemble de données
df['title_entities'] = df['title'].apply(extract_entities)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\REPOSITORIES\Project\DSTI-Project-Machine-Learning-with-Python-Labs\Code\Feature.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> import spacy
#       <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> # Charger le modèle SpaCy pré-entraîné
# ----> <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> nlp = spacy.load("en_core_web_sm")
#       <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> # Fonction pour extraire les entités nommées d'un titre
#       <a href='vscode-notebook-cell:/c%3A/REPOSITORIES/Project/DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> def extract_entities(title):
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File c:\Users\ndeblecker\AppData\Local\anaconda3\envs\ML_Project\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
l = dfwork.loc[:,"authors"]
list_authors = []
for list in l:
    for author in list:
        if author not in list_authors:
            list_authors.append(author)
print(list_authors)
print(dfwork['authors'].value_counts())


if len(list_authors) != len(set(list_authors)):
    print("There are duplicates in the list.")
else:
    print("No duplicates found in the list.")
# Out:
# ['J.K. Rowling', 'Mary GrandPré', 'W. Frederick Zimmerman', 'Douglas Adams', 'Stephen Fry', 'Bill Bryson', 'J.R.R. Tolkien', 'Alan  Lee', 'Chris   Smith', 'Christopher  Lee', 'Richard Taylor', 'Jude Fisher', 'Dave Thomas', 'David Heinemeier Hansson', 'Leon Breedt', 'Mike Clark', 'Thomas  Fuchs', 'Andreas  Schwarz', 'Gary Paulsen', 'Donna Ickes', 'Edward Sciranko', 'Keith Vasconcelles', 'Molly Hatchet', 'Dale Peck', 'Angela Knight', 'Sahara Kelly', 'Judy Mays', 'Marteeka Karland', 'Kate Douglas', 'Shelby Morgen', 'Lacey Savage', 'Kate Hill', 'Willa Okati', 'Delia Sherman', 'Patricia A. McKillip', 'Zilpha Keatley Snyder', 'Kate Horsley', 'Philippa Carr', 'Edward P. Jones', 'Kevin R. Free', 'Satyajit Das', 'Mark Smylie', 'John McPhee', 'William Howarth', 'Wendy Wasserstein', 'Heidi Hayes Jacobs', 'Heidi Boyd', 'Heidi Baker', 'Rolland Baker', 'Johanna Spyri', 'Beverly Cleary', 'Angelo  Rinaldi', 'Heidi Murkoff', 'Sharon Mazel', 'Arlene Eisenberg', 'Sandee Hathaway', 'Mark D. Widome', 'Heidi Fleiss', 'Libby Keatinge', 'Frank Herbert', 'Brian Herbert', 'Kevin J. Anderson', 'Gary Russell', 'Bryce Courtenay', 'John C. Maxwell', 'Stephen R. Graves', 'Thomas G. Addington', 'Dave Lakhani', 'Louis E. Catron', 'Adam Ginsberg', 'Marsha Collier', 'Chris Malta', 'Lisa Suttora', 'Julia Wilkinson', 'Lucas Carlson', 'Leonard Richardson', 'Ruby Ann Boxcar', 'Rob Orsini', 'Leo Tolstoy', 'Richard Pevear', 'Larissa Volokhonsky', 'David Magarshack', 'Priscilla Meyer', 'John Bayley', 'Marianne Sturman', 'Amy Mandelker', 'Constance Garnett', 'Louise Maude', 'Aylmer Maude', 'Gloria Goldreich', 'Anthony Thorlby', 'Mulk Raj Anand', 'E.M. Forster', 'John Banville', 'Eliot Ness', 'Oscar Fraley', 'Narendra Jadhav', 'V.T. Rajshekar', 'Y.N. Kly', 'Vasant Moon', 'Gail Omvedt', 'Eleanor Zelliot', 'Barry R. Cournoyer', 'John Carratello', 'Patty Carratello', 'Theresa Wright', 'George Smoot', 'Keay Davidson', "Madeleine L'Engle", 'Tara MacCarthy', 'Cynthia Harrod-Eagles', 'Charles Todd', 'Ewan McGregor', 'Charley Boorman', 'Robert Uhlig', 'Daniel Abraham', 'Charles Willeford', 'James Lee Burke', 'Lawrence Block', 'Elmore Leonard', 'Tom Wolfe', 'Edward Lear', 'Laura Huliska-Beith', 'Edward Mendelson', 'Quentin Blake', 'Henry Miller', 'Thomas H. Moore', 'Jiří Níl', 'Henry James', 'Patricia Crick', 'Gabriel Brownstein', 'Mary Cregan', 'Marguerite Duras', 'Barbara Bray', 'Richard Seever', 'Kahlil Gibran', 'Suheil Bushrui', 'Salma H. Al-Kuzbari', 'Jean Gibran', 'جبران خليل جبران', 'John Walbridge', 'Robin Waterfield', 'Anthony Rizcallah Ferris', 'Robert Louis Stevenson', 'Scott McKowen', 'N.C. Wyeth', 'Timothy Meis', 'Milo Winter', 'Deidre S. Laiken', 'A.J. McAllister', 'Ralph Ginzburg', 'Gabriel García Márquez', 'Dr. Seuss', 'Debbie Raleigh', 'Kevin Henkes', 'Patrick Süskind', 'Robert A. Heinlein', 'Nick  Webb', 'Terry Jones', 'Christopher Cerf', 'Susan Nanus', 'Norton Juster', 'Harry G. Frankfurt', 'Nick Flynn', 'Garry Wills', 'Abraham Lincoln', 'Michael McCurdy', 'Don DeLillo', 'Thomas Pynchon', 'Christophe Claro', 'Brice Matthieussent', 'Richard Fariña', 'Joan Didion', 'John Leonard', 'David Thomson', 'Paul Auster', 'Art Spiegelman', 'Luc Sante', 'Peter Moon', 'Preston B. Nichols', 'Nina Helms', 'Jared Diamond', 'Stephen Leeb', 'Glen C. Strathy', 'Joseph A. Tainter', 'Robert D. Putnam', 'Philip K. Howard', 'Joy Harjo', 'Gloria Bird', 'Beth Cuthand', 'Valerie Martinez', 'Patricia Blanco', 'Nikola Tesla', 'Marc J.  Seifer', 'William H. Terbo', 'Carol Dommermuth-Costa', 'David Hatcher Childress', 'Julie Elizabeth Leto', 'Leslie Kelly', 'Kimberly Raye', 'Chad Fowler', 'Andy Hunt', 'Maureen Kelly', 'CliffsNotes', 'William Golding', 'Victor Davis Hanson', 'Ephraim Sevela', 'Antonina W. Bouis', 'Alice Sebold', 'Sharyn McCrumb', 'Dave Shea', 'Molly E. Holzschlag', 'Elizabeth Castro', 'Michael Ochs', 'Patrick Javault', 'Ulrike Wasel', 'Chuck Klosterman', 'Jane Feather', 'Robert M. Pirsig', "Kevin O'Malley", 'Carol Heyer', 'Scott Goto', 'Ronald L. DiSanto', 'Thomas J. Steele' ...
# authors
# [Stephen King]                                                40
# [P.G. Wodehouse]                                              40
# [Rumiko Takahashi]                                            39
# [Orson Scott Card]                                            35
# [Agatha Christie]                                             33
#                                                               ..
# [Ian Glasper]                                                  1
# [Legs McNeil, Gillian McCain]                                  1
# [Adam Woog]                                                    1
# [Mikal Gilmore]                                                1
# [William T. Vollmann, Larry McCaffery, Michael Hemmingson]     1
# Name: count, Length: 6643, dtype: int64
# No duplicates found in the list.

# %%
#Creating text file recap of differents feature in database that we are gonna create
txt = open(r'')
dict = {txt.read()}
print(dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\natha\OneDrive\Documents\CIV-SurfaceProNDB\SCHOOL\DSTI\Cours\Python Labs\-DSTI-Project-Machine-Learning-with-Python-Labs\Code\Feature.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> #Creating text file recap of differents feature in database that we are gonna create
# ----> <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> txt = open(r'')
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> dict = {txt.read()}
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> print(dict)
#
# File c:\Users\natha\anaconda3\envs\PythonLabb\Lib\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
# Out:
# '{Bookid = [drop], \ntitle = [?? , drop],\nauthors =[?? , vector , drop],\navergage rate = [!!],\nisbn = [drop],\nisbn13 = [drop],\nlanguage_code = [?? , vector , drop],\nnum_pages = [!!],\nratings_count = [!! , drop],\ntext_reviews_count = [!! , drop],\npublication_date = [month , year , general],\npublisher = [vector , drop]}'

# %%
df_set1 = df.drop(['isbn13', 'bookID', 'isbn', 'title', 'publication_date', 'publisher'], axis = 1)

df_set1 = pd.concat([df_set1,pd.get_dummies(df_set1.language_code)],axis=1).drop(columns="language_code")
df_set1 = pd.concat([df_set1,pd.get_dummies(df_set1.authors)],axis=1).drop(columns="authors")

df_set1.keys()
# Out:
# Index(['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'ale', 'ara', 'en-CA', 'en-GB', 'en-US', 'eng',
#        ...
#        'Åsne Seierstad/Ingrid Christopherson',
#        'Émile Zola/Andrew Moore/Ernest Alfred Vizetelly',
#        'Émile Zola/Douglas Parmée', 'Émile Zola/Ernest Alfred Vizetelly',
#        'Émile Zola/Ernest Alfred Vizetelly/Henry Vizetelly',
#        'Émile Zola/Henri Mitterand',
#        'Émile Zola/Robert Lethbridge/Elinor Dorday',
#        'Émile Zola/Robin Buss/Brian  Nelson', 'Émile Zola/Roger Pearson',
#        'Éric-Emmanuel Schmitt'],
#       dtype='object', length=6674)

# %%
df_set1.isna().sum()
#df_set1.head()
# Out:
# average_rating                                0
# num_pages                                     0
# ratings_count                                 0
# text_reviews_count                            0
# ale                                           0
#                                              ..
# Émile Zola/Henri Mitterand                    0
# Émile Zola/Robert Lethbridge/Elinor Dorday    0
# Émile Zola/Robin Buss/Brian  Nelson           0
# Émile Zola/Roger Pearson                      0
# Éric-Emmanuel Schmitt                         0
# Length: 6674, dtype: int64

# %%
df_set1.corr()
values = df_set1.corr().values
dic = []
for i in range(len(values)):
    for j in range(len(values[i])):
        if abs(values[i][j]) >= 0.40 and i!=j:
            print((df_set1.columns[i],df_set1.corr().index[j]), values[i][j])

# %%
print(df.loc[df.publication_date.day == 31, 'publication_date'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21144\1577742786.py in ?()
# ----> 1 print(df.loc[df.publication_date.day == 31, 'publication_date'])
#
# c:\Users\natha\anaconda3\envs\PythonLabb\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'day'

# %%
print(df['publication_date'])
date = pd.to_datetime('11/31/2000', format = '%m/%d/%Y')
date.day
# Out:
# 0         9/16/2006
# 1          9/1/2004
# 2         11/1/2003
# 3          5/1/2004
# 4         9/13/2004
#             ...
# 11122    12/21/2004
# 11123     12/1/1988
# 11124      8/1/1993
# 11125     2/27/2007
# 11126     5/28/2006
# Name: publication_date, Length: 11127, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\natha\OneDrive\Documents\CIV-SurfaceProNDB\SCHOOL\DSTI\Cours\Python Labs\-DSTI-Project-Machine-Learning-with-Python-Labs\Code\Feature.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> print(df['publication_date'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> date = pd.to_datetime('11/31/2000', format = '%m/%d/%Y')
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/CIV-SurfaceProNDB/SCHOOL/DSTI/Cours/Python%20Labs/-DSTI-Project-Machine-Learning-with-Python-Labs/Code/Feature.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> date.day
#
# File c:\Users\natha\anaconda3\envs\PythonLabb\Lib\site-packages\pandas\core\tools\datetimes.py:1146, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1144         result = convert_listlike(argc, format)
#    1145 else:
# -> 1146     result = convert_listlike(np.array([arg]), format)[0]
#    1147     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1148         result = bool(result)  # TODO: avoid this kludge.
#
# File c:\Users\natha\anaconda3\envs\PythonLabb\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File c:\Users\natha\anaconda3\envs\PythonLabb\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:493, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: day is out of range for month, at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
